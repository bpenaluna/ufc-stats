# %% [markdown]
# # UFC Predictor

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import config

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option("display.max_columns", None, "display.max_rows", None)

# %%
sns.set_palette('Set2')

# %% [markdown]
# ## fight_stats

# %%
fight_stats = pd.read_csv(config.PATH + '/ufc-stats/data/scraped_data/fight_stats_raw.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[228], line 1
# ----> 1 fight_stats = pd.read_csv(config.PATH + '/ufc-stats/data/scraped_data/fight_stats_raw.csv')
#
# AttributeError: module 'config' has no attribute 'PATH'

# %%
# url = 'mssql+pyodbc://localhost/ufc?driver=ODBC+Driver+18+for+SQL+Server&trusted_connection=yes&TrustServerCertificate=yes'

# engine = create_engine(url)

# query = "SELECT * FROM fight_stats"
# fight_stats = pd.read_sql(query, engine)

# fight_stats.head()

# %%
fight_stats.columns
# Out:
# Index(['Unnamed: 0', 'title', 'method', 'round', 'time', 'time_format', 'ref',
#        'details', 'blue_fighter', 'red_fighter', 'blue_fighter_kd',
#        'red_fighter_kd', 'blue_fighter_sig_str', 'red_fighter_sig_str',
#        'blue_fighter_sig_str_perc', 'red_fighter_sig_str_perc',
#        'blue_fighter_total_str', 'red_fighter_total_str', 'blue_fighter_td',
#        'red_fighter_td', 'blue_fighter_td_perc', 'red_fighter_td_perc',
#        'blue_fighter_sub_att', 'red_fighter_sub_att', 'blue_fighter_rev',
#        'red_fighter_rev', 'blue_fighter_ctrl', 'red_fighter_ctrl',
#        'blue_fighter_sig_str_head', 'red_fighter_sig_str_head',
#        'blue_fighter_sig_str_body', 'red_fighter_sig_str_body',
#        'blue_fighter_sig_str_leg', 'red_fighter_sig_str_leg',
#        'blue_fighter_sig_str_distance', 'red_fighter_sig_str_distance',
#        'blue_fighter_sig_str_clinch', 'red_fighter_sig_str_clinch',
#        'blue_fighter_sig_str_ground', 'red_fighter_sig_str_ground'],
#       dtype='object')

# %%
def get_perc(x):
    
    y = x.split(' of ')
    
    if len(y) == 2:
        landed, total = int(y[0]), int(y[1])
    else:
        return np.nan
        
    if total > 0:
        return round(landed / total, 2)
    else:
        return 0

# %%
cols = ['blue_fighter_sig_str', 'red_fighter_sig_str',
        'blue_fighter_total_str', 'red_fighter_total_str',
        'blue_fighter_td', 'red_fighter_td',
        'blue_fighter_sig_str_head', 'red_fighter_sig_str_head',
        'blue_fighter_sig_str_body', 'red_fighter_sig_str_body',
        'blue_fighter_sig_str_leg', 'red_fighter_sig_str_leg',
        'blue_fighter_sig_str_distance', 'red_fighter_sig_str_distance',
        'blue_fighter_sig_str_clinch', 'red_fighter_sig_str_clinch',
        'blue_fighter_sig_str_ground', 'red_fighter_sig_str_ground']

for col in cols:
    fight_stats[col + '_perc'] = fight_stats[col].map(lambda x: get_perc(x))
    fight_stats[col + '_att'] = fight_stats[col].map(lambda x: int(x.split(' of ')[0]))

fight_stats.drop(columns=cols, inplace=True)

fight_stats.head()
# Out:
#    Unnamed: 0                         title                method  round  \
# 0           0  UFC Featherweight Title Bout  Decision - Unanimous      5
# 1           1              Lightweight Bout                KO/TKO      2
# 2           2              Lightweight Bout                KO/TKO      2
# 3           3              Heavyweight Bout  Decision - Unanimous      3
# 4           4              Lightweight Bout            Submission      1
#
#    time        time_format              ref  \
# 0     5  5 Rnd (5-5-5-5-5)     Marc Goddard
# 1     4      3 Rnd (5-5-5)        Herb Dean
# 2     4      3 Rnd (5-5-5)  Daniel Movahedi
# 3     5      3 Rnd (5-5-5)     Marc Goddard
# 4     3      3 Rnd (5-5-5)  Daniel Movahedi
#
#                                              details           blue_fighter  \
# 0  Ben Cartlidge46 - 49.Sal D'amato46 - 49.Clemen...  Alexander Volkanovski
# 1                         Punches to Head From Mount             Dan Hooker
# 2                          Punches to Head On Ground          Rafael Fiziev
# 3  Ben Cartlidge28 - 29.Sal D'amato28 - 29.Evan F...            Tai Tuivasa
# 4                       Neck Crank From Back Control       Quillan Salkilld
#
#           red_fighter  blue_fighter_kd  red_fighter_kd  \
# 0         Diego Lopes                0               0
# 1  Benoit Saint Denis                0               0
# 2      Mauricio Ruffy                0               1
# 3   Tallison Teixeira                0               0
# 4     Jamie Mullarkey                0               0
#
#    blue_fighter_sig_str_perc  red_fighter_sig_str_perc  blue_fighter_td_perc  \
# 0                       0.61                      0.44                  0.29
# 1                       0.64                      0.76                  0.00
# 2                       0.55                      0.62                  0.00
# 3                       0.72                      0.69                  0.00
# 4                       0.62                      0.25                  0.67
#
#    red_fighter_td_perc  blue_fighter_sub_att  red_fighter_sub_att  \
# 0                 0.40                     1                    0
# 1                 0.22                     2                    2
# 2                 0.00                     0                    0
# 3                 0.33                     0                    0
# 4                 1.00                     1                    0
#
#    blue_fighter_rev  red_fighter_rev blue_fighter_ctrl red_fighter_ctrl  \
# 0                 0                0              2:49             1:50
# 1                 0                0              0:28             6:14
# 2                 0                0              0:00             0:45
# 3                 0                0              3:58             7:00
# 4                 0                0              0:39             1:14
#
#    blue_fighter_sig_str_att  red_fighter_sig_str_att  \
# 0                        98                       70
# 1                        30                       97
# 2                        36                       55
# 3                        42                       51
# 4                         5                        1
#
#    blue_fighter_total_str_perc  blue_fighter_total_str_att  \
# 0                         0.63                         112
# 1                         0.75                          51
# 2                         0.55                          37
# 3                         0.76                          56
# 4                         0.86                          18
#
#    red_fighter_total_str_perc  red_fighter_total_str_att  blue_fighter_td_att  \
# 0                        0.46                         74                    2
# 1                        0.83                        170                    0
# 2                        0.65                         60                    0
# 3                        0.81                        117                    0
# 4                        0.67                          6                    2
#
#    red_fighter_td_att  blue_fighter_sig_str_head_perc  \
# 0                   2                            0.61
# 1                   2                            0.59
# 2                   0                            0.29
# 3                   3                            0.58
# 4                   1                            0.50
#
#    blue_fighter_sig_str_head_att  red_fighter_sig_str_head_perc  \
# 0                             72                           0.34
# 1                             19                           0.73
# 2                              9                           0.58
# 3                             21                           0.65
# 4                              1                           0.25
#
#    red_fighter_sig_str_head_att  blue_fighter_sig_str_body_perc  \
# 0                            33                            0.50
# 1                            83                            0.67
# 2                            45                            0.79
# 3                            39                            1.00
# 4                             1                            0.50
#
#    blue_fighter_sig_str_body_att  red_fighter_sig_str_body_perc  \
# 0                              3                           0.52
# 1                              8                           1.00
# 2                             15                           1.00
# 3                             10                           0.91
# 4                              1                           0.00
#
#    red_fighter_sig_str_body_att  blue_fighter_sig_str_leg_perc  \
# 0                            17                           0.64
# 1                            14                           1.00
# 2                             4                           0.75
# 3                            10                           0.92
# 4                             0                           0.75
#
#    blue_fighter_sig_str_leg_att  red_fighter_sig_str_leg_perc  \
# 0                            23                          0.74
# 1                             3                          0.00
# 2                            12                          0.86
# 3                            11                          0.67
# 4                             3                          0.00
#
#    red_fighter_sig_str_leg_att  blue_fighter_sig_str_distance_perc  \
# 0                           20                                0.59
# 1                            0                                0.64
# 2                            6                                0.53
# 3                            2                                0.77
# 4                            0                                0.60
#
#    blue_fighter_sig_str_distance_att  red_fighter_sig_str_distance_perc  \
# 0                                 88                               0.43
# 1                                 28                               0.62
# 2                                 34                               0.64
# 3                                 27                               0.55
# 4                                  3                               0.00
#
#    red_fighter_sig_str_distance_att  blue_fighter_sig_str_clinch_perc  \
# 0                                66                              0.75
# 1                                20                              0.67
# 2                                42                              1.00
# 3                                26                              0.65
# 4                                 0                              0.67
#
#    blue_fighter_sig_str_clinch_att  red_fighter_sig_str_clinch_perc  \
# 0                                3                             0.75
# 1                                2                             0.91
# 2                                2                             0.50
# 3                               11                             1.00
# 4                                2                             1.00
#
#    red_fighter_sig_str_clinch_att  blue_fighter_sig_str_ground_perc  \
# 0                               3                              1.00
# 1                              10                              0.00
# 2                               1                              0.00
# 3                               4                              0.67
# 4                               1                              0.00
#
#    blue_fighter_sig_str_ground_att  red_fighter_sig_str_ground_perc  \
# 0                                7                             0.50
# 1                                0                             0.80
# 2                                0                             0.60
# 3                                4                             0.91
# 4                                0                             0.00
#
#    red_fighter_sig_str_ground_att
# 0                               1
# 1                              67
# 2                              12
# 3                              21
# 4                               0

# %%
fight_stats.isna().sum()
# Out:
# Unnamed: 0                             0
# title                                  0
# method                                 0
# round                                  0
# time                                   0
# time_format                            0
# ref                                   26
# details                               74
# blue_fighter                           0
# red_fighter                            0
# blue_fighter_kd                        0
# red_fighter_kd                         0
# blue_fighter_sig_str_perc              0
# red_fighter_sig_str_perc               0
# blue_fighter_td_perc                   0
# red_fighter_td_perc                    0
# blue_fighter_sub_att                   0
# red_fighter_sub_att                    0
# blue_fighter_rev                       0
# red_fighter_rev                        0
# blue_fighter_ctrl                      0
# red_fighter_ctrl                       0
# blue_fighter_sig_str_att               0
# red_fighter_sig_str_att                0
# blue_fighter_total_str_perc            0
# blue_fighter_total_str_att             0
# red_fighter_total_str_perc             0
# red_fighter_total_str_att              0
# blue_fighter_td_att                    0
# red_fighter_td_att                     0
# blue_fighter_sig_str_head_perc         0
# blue_fighter_sig_str_head_att          0
# red_fighter_sig_str_head_perc          0
# red_fighter_sig_str_head_att           0
# blue_fighter_sig_str_body_perc         0
# blue_fighter_sig_str_body_att          0
# red_fighter_sig_str_body_perc          0
# red_fighter_sig_str_body_att           0
# blue_fighter_sig_str_leg_perc          0
# blue_fighter_sig_str_leg_att           0
# red_fighter_sig_str_leg_perc           0
# red_fighter_sig_str_leg_att            0
# blue_fighter_sig_str_distance_perc     0
# blue_fighter_sig_str_distance_att      0
# red_fighter_sig_str_distance_perc      0
# red_fighter_sig_str_distance_att       0
# blue_fighter_sig_str_clinch_perc       0
# blue_fighter_sig_str_clinch_att        0
# red_fighter_sig_str_clinch_perc        0
# red_fighter_sig_str_clinch_att         0
# blue_fighter_sig_str_ground_perc       0
# blue_fighter_sig_str_ground_att        0
# red_fighter_sig_str_ground_perc        0
# red_fighter_sig_str_ground_att         0
# dtype: int64

# %% [markdown]
# ## fighter_stats

# %%
fighter_stats = pd.read_csv('C:/Users/Ben/Documents/ufc-stats/data/scraped_data/fighter_stats_raw.csv')

# %%
# query = "SELECT * FROM fighter_stats"
# fighter_stats = pd.read_sql(query, engine)

# fighter_stats.head()

# %%
fighter_stats.shape
# Out:
# (4452, 18)

# %%
fighter_stats = fighter_stats.replace('--', np.nan)

# %%
fighter_stats.weight = fighter_stats.weight.str.replace(' lbs.', '').astype(np.float64)
fighter_stats.reach = fighter_stats.reach.str.replace('"', '').astype(np.float64)
fighter_stats.str_acc = fighter_stats.str_acc.str.replace('%', '').astype(np.float64)
fighter_stats.sig_str_def = fighter_stats.sig_str_def.str.replace('%', '').astype(np.float64)
fighter_stats.td_acc = fighter_stats.td_acc.str.replace('%', '').astype(np.float64)
fighter_stats.td_def = fighter_stats.td_def.str.replace('%', '').astype(np.float64)

# %%
fighter_stats.dob = fighter_stats.dob.map(lambda x: pd.to_datetime(x, format='%b %d, %Y'))

# %%
def inches_from_feet(x):
    if pd.isna(x):
        return np.nan
    else:
        y = x.split('\'')
        feet, inches = int(y[0]), int(y[1][:-1])
        return int(feet * 11 + inches)

# %%
fighter_stats.height = fighter_stats.height.map(lambda x: inches_from_feet(x))

# %%
fighter_stats.isna().sum()
# Out:
# Unnamed: 0           0
# name                 0
# wins                 0
# losses               0
# draws                0
# height             316
# weight              86
# reach             1938
# stance             847
# dob                504
# sig_str_pm           0
# str_acc              0
# strikes_abs_pm       0
# sig_str_def          0
# td_avg               0
# td_acc               0
# td_def               0
# sub_avg              0
# dtype: int64

# %%
fighter_stats.dtypes
# Out:
# Unnamed: 0                 int64
# name                      object
# wins                       int64
# losses                     int64
# draws                     object
# height                   float64
# weight                   float64
# reach                    float64
# stance                    object
# dob               datetime64[ns]
# sig_str_pm               float64
# str_acc                  float64
# strikes_abs_pm           float64
# sig_str_def              float64
# td_avg                   float64
# td_acc                   float64
# td_def                   float64
# sub_avg                  float64
# dtype: object

# %%
fighter_stats.wins = fighter_stats.wins.astype(int)
fighter_stats.losses = fighter_stats.losses.astype(int)
fighter_stats.sig_str_pm = fighter_stats.sig_str_pm.astype(np.float64)
fighter_stats.strikes_abs_pm = fighter_stats.strikes_abs_pm.astype(np.float64)
fighter_stats.td_avg = fighter_stats.td_avg.astype(np.float64)
fighter_stats.sub_avg = fighter_stats.sub_avg.astype(np.float64)

# %%
def sum_draws(x):
    pattern = pattern = '\((\d+) NC\)'
    match = re.search(pattern, x)
    if not match:
        return int(x)
    return int(match.group(1))

# %%
fighter_stats.draws = fighter_stats.draws.map(lambda x: sum_draws(x))

# %%
fighter_stats.height = fighter_stats.height.fillna(fighter_stats.height.mean())
fighter_stats.reach = fighter_stats.reach.fillna(fighter_stats.reach.mean())
fighter_stats.weight = fighter_stats.weight.fillna(fighter_stats.weight.mean())
fighter_stats.dob = fighter_stats.dob.fillna(fighter_stats.dob.median())

# %%
fighter_stats['total_fights'] = fighter_stats.wins + fighter_stats.losses + fighter_stats.draws

# %%
fighter_stats['birth_year'] = fighter_stats.dob.map(lambda x: x.year)
fighter_stats['birth_month'] = fighter_stats.dob.map(lambda x: x.month)
fighter_stats['birth_day'] = fighter_stats.dob.map(lambda x: x.day)

# %%
stance_mode = fighter_stats.stance.mode()
fighter_stats.stance = fighter_stats.stance.replace(' ', stance_mode[0])

# %%
fighter_stats.head()
# Out:
#    Unnamed: 0             name  wins  losses  draws     height  weight  \
# 0           0        Tom Aaron     5       3      0  64.770793   155.0
# 1           1     Danny Abbadi     4       6      0  66.000000   155.0
# 2           2  Nariman Abbasov    28       4      0  63.000000   155.0
# 3           3     Darion Abbey     9       5      0  68.000000   265.0
# 4           4     David Abbott    10      15      0  66.000000   265.0
#
#        reach    stance        dob  sig_str_pm  str_acc  strikes_abs_pm  \
# 0  71.556086       NaN 1978-07-13        0.00      0.0            0.00
# 1  71.556086  Orthodox 1983-07-03        3.29     38.0            4.41
# 2  66.000000  Orthodox 1994-02-01        3.00     20.0            5.67
# 3  80.000000  Orthodox 1993-02-25        8.44     50.0           14.06
# 4  71.556086    Switch 1965-04-26        1.35     30.0            3.55
#
#    sig_str_def  td_avg  td_acc  td_def  sub_avg  total_fights  birth_year  \
# 0          0.0    0.00     0.0     0.0      0.0             8        1978
# 1         57.0    0.00     0.0    77.0      0.0            10        1983
# 2         46.0    0.00     0.0    66.0      0.0            32        1994
# 3         28.0    0.00     0.0     0.0      0.0            14        1993
# 4         38.0    1.07    33.0    66.0      0.0            25        1965
#
#    birth_month  birth_day
# 0            7         13
# 1            7          3
# 2            2          1
# 3            2         25
# 4            4         26

# %% [markdown]
# ## Save to Database

# %%
from sqlalchemy import create_engine

# %%
conn_str = f"mssql+pyodbc://{config.DB_SERVER}/{config.DB_NAME}?driver=ODBC+Driver+18+for+SQL+Server&trusted_connection=yes&TrustServerCertificate=yes"
engine = create_engine(conn_str)

# %%
fighter_stats.to_sql('fighter_stats', con=engine, if_exists='replace', index=False)
print('Table (fighter_stats) created successfully!')
# Out:
# Table (fighter_stats) created successfully!

# %%
fight_stats.to_sql('fight_stats', con=engine, if_exists='replace', index=False)
print("Table (fight_stats) created successfully!")
# Out:
# Table (fight_stats) created successfully!

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
fig, ((bp1, bp2), (hist1, hist2)) = plt.subplots(2, 2, sharex=True, figsize=(13, 4), gridspec_kw={"height_ratios": (.15, .85)})

sns.boxplot(fight_stats.blue_fighter_sig_str_perc, orient='h', ax=bp1)
sns.histplot(data=fight_stats, x='blue_fighter_sig_str_perc', bins=40, ax=hist1)
bp1.set_title('Distribution of Blue Fighter Significant Strike Percentage')

sns.boxplot(fight_stats.red_fighter_sig_str_perc, orient='h', ax=bp2)
sns.histplot(data=fight_stats, x='red_fighter_sig_str_perc', bins=40, ax=hist2)
bp2.set_title('Distribution of Red Fighter Significant Strike Percentage');

# %%
fig = plt.figure(figsize=(11, 4))

sns.histplot(data=fighter_stats, x='dob', bins=30)
plt.title('Distribution of Date of Birth')
plt.xlabel('Date of Birth');

# %%
fig = plt.figure(figsize=(11, 3))
sns.histplot(data=fighter_stats, x='stance')
plt.title('Class Counts of Stance');

# %%
fig = plt.figure(figsize=(11,3))
mask = (fighter_stats.wins < 100) & (fighter_stats.losses < 100)
sns.histplot(data=fighter_stats.loc[mask, ['wins', 'losses', 'draws']], bins=40, multiple='fill')
plt.title('Distribution of Draws')
plt.xticks(rotation=90);

# %%
fig = plt.figure(figsize=(11, 3))
sns.scatterplot(data=fighter_stats, x='dob', y='total_fights')
plt.title('Total Fights Against Date of Birth')
plt.xlabel('Date of Birth');

# %%
fig = plt.figure(figsize=(11, 3))
mask = (fighter_stats.wins < 50) & (fighter_stats.losses < 50)
sns.boxplot(data=fighter_stats[mask], x='birth_month', y='wins')
plt.title('Birth Month Against Number of Wins')
plt.xlabel('Birth Month')
plt.xticks(range(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']);

# %%
fig = plt.figure(figsize=(11, 3))
mask = (fighter_stats.wins < 50) & (fighter_stats.losses < 50)
sns.scatterplot(data=fighter_stats[mask], x='birth_year', y='wins')
plt.title('Birth Year Against Number of Wins')
plt.xlabel('Birth Year');
